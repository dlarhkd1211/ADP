# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
df = pd.read_csv('Groceries_dataset.csv')

# %%
df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %%
df_sort = df.sort_values(['Member_number','Date']).reset_index(drop=True)

# %%
df_sort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38765 entries, 4843 to 25489
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  int64
#  1   Date             38765 non-null  object
#  2   itemDescription  38765 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.2+ MB

# %%
df_sort
# Out:
#        Member_number        Date      itemDescription
# 0               1000  15-03-2015              sausage
# 1               1000  15-03-2015           whole milk
# 2               1000  15-03-2015  semi-finished bread
# 3               1000  15-03-2015               yogurt
# 4               1000  24-06-2014           whole milk
# ...              ...         ...                  ...
# 38760           5000  10-02-2015                 soda
# 38761           5000  10-02-2015      root vegetables
# 38762           5000  10-02-2015  semi-finished bread
# 38763           5000  16-11-2014         bottled beer
# 38764           5000  16-11-2014     other vegetables
#
# [38765 rows x 3 columns]

# %%
group_df = pd.DataFrame(columns = ['Member_number','Date','itemDescription'])

# %%
mem0 = 0
Date0 = ''
for i in range(len(df_sort)):
    mem1, Date1 = df_sort.iloc[i,:2]
    if [mem0, Date0] != [mem1, Date1]:
        group_df.append([mem0, Date0, li])
        mem0, Date0 = mem1, Date1
        li = []
    li.append(df_sort['itemDescription'][i])
#     print(li)
# Out:
# ['sausage']
# ['sausage', 'whole milk']
# ['sausage', 'whole milk', 'semi-finished bread']
# ['sausage', 'whole milk', 'semi-finished bread', 'yogurt']
# ['whole milk']
# ['whole milk', 'pastry']
# ['whole milk', 'pastry', 'salty snack']
# ['canned beer']
# ['canned beer', 'misc. beverages']
# ['sausage']
# ['sausage', 'hygiene articles']
# ['soda']
# ['soda', 'pickled vegetables']
# ['frankfurter']
# ['frankfurter', 'curd']
# ['sausage']
# ['sausage', 'whole milk']
# ['sausage', 'whole milk', 'rolls/buns']
# ['whole milk']
# ['whole milk', 'soda']
# ['beef']
# ['beef', 'white bread']
# ['frankfurter']
# ['frankfurter', 'soda']
# ['frankfurter', 'soda', 'whipped/sour cream']
# ['frozen vegetables']
# ['frozen vegetables', 'other vegetables']
# ['butter']
# ['butter', 'whole milk']
# ['tropical fruit']
# ['tropical fruit', 'sugar']
# ['butter milk']
# ['butter milk', 'specialty chocolate']
# ['sausage']
# ['sausage', 'rolls/buns']
# ['root vegetables']
# ...
